# %% [markdown]
# # Bonus challenge
# Refer to bonus.sql for the queries to create the views.
# I used sql to bin the salary ranges and therefore I was unable to use plt.hist() because my data was already binned. Result is the same, I just learned a bit more about SQL.

# %%
import pandas as pd
from sqlalchemy import create_engine
from config import username,password

# %%
db_url = f'postgresql+psycopg2://{username}:{password}@127.0.0.1/sql-challenge'

# %%
engine = create_engine(db_url)

# %%
salaries_df = pd.read_sql(sql="select * from salary_counts",con=engine)

# %%
salaries_df
# Out:
#       salary_range   count
# 0    [40000-50000)  158465
# 1    [50000-60000)   57915
# 2    [60000-70000)   41413
# 3    [70000-80000)   24814
# 4    [80000-90000)   11845
# 5   [90000-100000)    4284
# 6  [100000-110000)    1069
# 7  [110000-120000)     195
# 8  [120000-130000)      24

# %%
avg_salary_df = pd.read_sql(sql="select * from avg_salary",con=engine)

# %%
avg_salary_df
# Out:
#    avg_salary               title
# 0    58503.29        Senior Staff
# 1    58465.27               Staff
# 2    51531.04             Manager
# 3    48580.51    Technique Leader
# 4    48539.78            Engineer
# 5    48506.75     Senior Engineer
# 6    48493.20  Assistant Engineer

# %%
import matplotlib.pyplot as plt
import os

# %%
plt.figure(figsize=(20,12))
plt.rcParams.update({'font.size': 14})
plt.barh(salaries_df['salary_range'],salaries_df['count'])
plt.xlabel('Count of Employees')
plt.ylabel('Salary Range')
plt.title('Number of Employee Salaries')
plt.savefig(os.path.join("Images","bonus_plot_hist.png"))
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.rcParams.update({'font.size': 14})
plt.barh(avg_salary_df['title'],avg_salary_df['avg_salary'])
plt.ylabel('Job Title')
plt.xlabel('Average Salary')
plt.title('Average Salary by Job Title')
plt.savefig(os.path.join("Images","bonus_plot_bar.png"))
plt.show()
